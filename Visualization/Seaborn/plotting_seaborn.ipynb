# %% [markdown]
# # Plotting in Seaborn Library

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Important Points to remember:
# - Data (df)
# - Plot type
# - axes (x/y)
# - grouping (color/hue)
# - Plot size
# - color palletes
# - plot style
# - interpretation

# %%
#load dataset
df = sns.load_dataset('titanic')
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# scatter plot
# plot size
plt.figure(figsize=(5,5))
sns.scatterplot(x='age', y='fare', data=df, hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# scatter plot
# defining colors
colors = {'male': 'green', 'female': 'red'}
# plot size
plt.figure(figsize=(5,5))
sns.scatterplot(x='age', y='fare', data=df, hue='sex', palette=colors)
# labels
plt.xlabel('Age')
plt.ylabel('Fare')
# title
plt.title('Age vs Fare')
# saving a plot //better to save in 300dpi as 600 dpi is heay and necessary in extreme need. save in png file
plt.savefig('./outputs/Age vs Fare.png', dpi=300)

# %%
# setting backgroud theme
sns.set_theme(style='darkgrid', font='Times New Roman')
# plot size
plt.figure(figsize=(16,9))
# labels
plt.xlabel('Age')
plt.ylabel('Fare')
# title
plt.title('Age vs Fare')
sns.scatterplot(x='age', y='fare', data=df,size='fare', hue='class')
# Out:
# <Axes: title={'center': 'Age vs Fare'}, xlabel='Age', ylabel='Fare'>

# %% [markdown]
# - Get key insights from this plot.

# %%
# now boxplot
# setting backgroud theme
sns.set_theme(style='darkgrid', font_scale=1,font='Times New Roman')
# plot size
plt.figure(figsize=(16,9))
# labels
plt.xlabel('Class')
plt.ylabel('Fare')
# title
plt.title('Age vs Fare-BoxenPlot')
sns.boxenplot(x='class', y='fare', data=df, hue='sex')
# change legend position and name
plt.legend(loc='upper right', title='Gender')
# changing x tick labels
plt.xticks(rotation=45)
# changing x tick names
plt.xticks([0, 1, 2], ['First Class', 'Second Class', 'Third Class'])
# Out:
# ([<matplotlib.axis.XTick at 0x1524b85ca90>,
# ...
#  [Text(0, 0, 'First Class'),
#   Text(1, 0, 'Second Class'),
#   Text(2, 0, 'Third Class')])

# %%
# scatter plot using plotly
import plotly.express as px
px.scatter(df, x='age', y='fare', color='sex')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\ProgramData\miniconda3\envs\eda\lib\site-packages\IPython\core\formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File c:\ProgramData\miniconda3\envs\eda\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\ProgramData\miniconda3\envs\eda\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...
