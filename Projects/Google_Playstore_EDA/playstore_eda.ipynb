# %% [markdown]
# # Google PlayStore EDA Analysis
# ## Introduction
# This project is a part of the Data Science and Business Analytics course at IIIT-B. The objective of this project is to perform Exploratory Data Analysis on the Google PlayStore dataset and answer the following questions:
# 1. What are the most popular categories in the Google PlayStore?
# 2. BLah Blah blah!!!

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Data Loading and Exploration | Cleaning

# %% [markdown]
# - Loading Files

# %%
df = pd.read_csv('googleplaystore.csv')

# %% [markdown]
# - An insight on top 5 rows

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# - An important point

# %%
# set options to be max for columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# hiding all warnings to keeps things tidy
import warnings
warnings.filterwarnings('ignore')

# %%
# A look at columns
print(f"The names of columns in this dataset are: {df.columns}.")
# Out:
# The names of columns in this dataset are: Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object').

# %%
# row vs columns
print(f"The number of rows in this dataset are {df.shape[0]} and the number of columns are {df.shape[1]}.")
# Out:
# The number of rows in this dataset are 10841 and the number of columns are 13.

# %% [markdown]
# - Overall info of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# - Let's check how many numeric columns/variables present

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# - **Observation about Dataset:**\
# Only 2 variables shown in describe screen as numeric but in dataset we noticed there are more than two numeric variables.

# %% [markdown]
# - To make `Size` a numeric column

# %%
df['Size'].nunique()
# Out:
# 461

# %% [markdown]
# ---
# - Three types of values observed
#   - "Varies with device"
#   - M
#   - k
# ---

# %%
# checking for missing value
df['Size'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - No missing value so good to go!

# %% [markdown]
# To verify that 3 types of values are contained in `Size`

# %%
# checking for "M" in column
df['Size'].str.contains("M").sum()
# Out:
# np.int64(8830)

# %%
# checking for "k" in column
df['Size'].str.contains("k").sum()
# Out:
# np.int64(316)

# %%
# checking for "Varies with device" in column
df['Size'].str.contains("Varies with device").sum()
# Out:
# np.int64(1695)

# %%
# final verifiation that all datapoints have been taken into account
1695+316+8830 == len(df['Size'])
# Out:
# True

# %%
# convert size column into bytes(b)
# let's define a function
def convert_size(size):
    if 'k' in size:
        return float(size.replace('k', '')) * 1024
    elif 'M' in size:
        return float(size.replace('M', '')) * 1024 * 1024
    elif 'Varies with device' in size:
        return np.nan
    return size

# %%
# apply the function
df['Size'] = convert_size(df['Size'])
df['Size']
# Out:
# 0         19922944.0
# 1         14680064.0
# 2          9122611.2
# 3         26214400.0
# 4          2936012.8
# 5          5872025.6
# 6         19922944.0
# 7         30408704.0
# 8         34603008.0
# 9          3250585.6
# 10        29360128.0
# 11        12582912.0
# 12        20971520.0
# 13        22020096.0
# 14        38797312.0
# 15         2831155.2
# 16         5767168.0
# 17        17825792.0
# 18        40894464.0
# 19        32505856.0
# 20        14680064.0
# 21        12582912.0
# 22         4404019.2
# 23         7340032.0
# 24        24117248.0
# 25         6291456.0
# 26        26214400.0
# 27         6396313.6
# 28         4823449.6
# 29         4404019.2
# 30         9646899.2
# 31         5452595.2
# 32        11534336.0
# 33        11534336.0
# 34         4404019.2
# 35         9646899.2
# 36        25165824.0
# 37               NaN
# 38        11534336.0
# 39         9856614.4
# 40        15728640.0
# 41        10485760.0
# 42               NaN
# ...

# %%
# A look into data set
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size     Installs  Type Price Content Rating  \
# 0      159  19922944.0      10,000+  Free     0       Everyone
# 1      967  14680064.0     500,000+  Free     0       Everyone
# 2    87510   9122611.2   5,000,000+  Free     0       Everyone
# 3   215644  26214400.0  50,000,000+  Free     0           Teen
# 4      967   2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
# renaming size column
df.rename(columns={'Size':'Size_in_bytes'}, inplace=True)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0      159     19922944.0      10,000+  Free     0       Everyone
# 1      967     14680064.0     500,000+  Free     0       Everyone
# 2    87510      9122611.2   5,000,000+  Free     0       Everyone
# 3   215644     26214400.0  50,000,000+  Free     0           Teen
# 4      967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
# Conversion of bytes into Mb
df['Size_in_MB']=df['Size_in_bytes'].apply(lambda x: x/(1024*1024))

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0      159     19922944.0      10,000+  Free     0       Everyone
# 1      967     14680064.0     500,000+  Free     0       Everyone
# 2    87510      9122611.2   5,000,000+  Free     0       Everyone
# 3   215644     26214400.0  50,000,000+  Free     0           Teen
# 4      967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ## Installs column
# - Since `Size` has been taken care of now it's time for `Installs` column.

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %% [markdown]
# - Checking for **missing values** if any!

# %%
df['Installs'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Now only problem remains is to remove `+` sign from column to make it numerical.
# Steps to do so:
# 1. Remove `+` sign
# 2. Remove `,` sign
# 3. Convert into `int` as values are discrete

# %%
# removal of '+' sign
df['Installs']=df['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000        1579
# 10,000,000       1252
# 100,000          1169
# 10,000           1054
# 1,000             908
# 5,000,000         752
# 100               719
# 500,000           539
# 50,000            479
# 5,000             477
# 100,000,000       409
# 10                386
# 500               330
# 50,000,000        289
# 50                205
# 5                  82
# 500,000,000        72
# 1                  67
# 1,000,000,000      58
# 0                  15
# Name: count, dtype: int64

# %%
# removal of "," sign
df['Installs']=df['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           908
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: count, dtype: int64

# %%
# conversion into integer type
df['Installs']=df['Installs'].apply(lambda x: int(x))

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           908
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: count, dtype: int64

# %% [markdown]
# - Let's have a look how many numerical columns now!

# %%
df.describe()
# Out:
#             Rating       Reviews  Size_in_bytes      Installs   Size_in_MB
# count  9367.000000  1.084100e+04   9.146000e+03  1.084100e+04  9146.000000
# mean      4.191513  4.441119e+05   2.255921e+07  1.546291e+07    21.514141
# std       0.515735  2.927629e+06   2.368595e+07  8.502557e+07    22.588679
# min       1.000000  0.000000e+00   8.704000e+03  0.000000e+00     0.008301
# 25%       4.000000  3.800000e+01   5.138022e+06  1.000000e+03     4.900000
# 50%       4.300000  2.094000e+03   1.363149e+07  1.000000e+05    13.000000
# 75%       4.500000  5.476800e+04   3.145728e+07  5.000000e+06    30.000000
# max       5.000000  7.815831e+07   1.048576e+08  1.000000e+09   100.000000

# %% [markdown]
# ## Price Column

# %%
df['Price'].value_counts()
# Out:
# Price
# 0          10041
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
# $3.99         63
# $1.49         46
# $5.99         30
# $2.49         26
# $9.99         21
# $6.99         13
# $399.99       12
# $14.99        11
# $4.49          9
# $29.99         7
# $3.49          7
# $7.99          7
# $24.99         7
# $5.49          6
# $19.99         6
# $6.49          5
# $8.99          5
# $12.99         5
# $11.99         5
# $10.00         3
# $1.00          3
# $16.99         3
# $2.00          3
# $17.99         2
# $10.99         2
# $9.00          2
# $79.99         2
# $7.49          2
# $3.95          2
# $33.99         2
# $1.70          2
# $13.99         2
# $8.49          2
# $39.99         2
# $1.50          1
# $25.99         1
# $74.99         1
# $15.99         1
# $3.88          1
# $1.76          1
# $3.02          1
# $400.00        1
# $4.84          1
# $2.50          1
# $1.59          1
# $1.61          1
# $4.77          1
# ...

# %% [markdown]
# **Steps to make it numerical:**\
# 1. Remove `$` sign
# 2. Typecasting to `float` type

# %%
df['Price'] = df['Price'].apply(lambda x: x.replace('$', '') if '$' in str(x) else x)

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10041
# 0.99        148
# 2.99        129
# 1.99         73
# 4.99         72
# 3.99         63
# 1.49         46
# 5.99         30
# 2.49         26
# 9.99         21
# 6.99         13
# 399.99       12
# 14.99        11
# 4.49          9
# 29.99         7
# 3.49          7
# 7.99          7
# 24.99         7
# 5.49          6
# 19.99         6
# 6.49          5
# 8.99          5
# 12.99         5
# 11.99         5
# 10.00         3
# 1.00          3
# 16.99         3
# 2.00          3
# 17.99         2
# 10.99         2
# 9.00          2
# 79.99         2
# 7.49          2
# 3.95          2
# 33.99         2
# 1.70          2
# 13.99         2
# 8.49          2
# 39.99         2
# 1.50          1
# 25.99         1
# 74.99         1
# 15.99         1
# 3.88          1
# 1.76          1
# 3.02          1
# 400.00        1
# 4.84          1
# 2.50          1
# 1.59          1
# 1.61          1
# 4.77          1
# 5.00          1
# 1.29          1
# 379.99        1
# ...

# %%
# type casting using lambda function
df['Price'] = df['Price'].apply(lambda x: float(x))

# %%
df.describe()
# Out:
#             Rating       Reviews  Size_in_bytes      Installs         Price  \
# count  9367.000000  1.084100e+04   9.146000e+03  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05   2.255921e+07  1.546291e+07      1.027273
# std       0.515735  2.927629e+06   2.368595e+07  8.502557e+07     15.948971
# min       1.000000  0.000000e+00   8.704000e+03  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01   5.138022e+06  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   1.363149e+07  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04   3.145728e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   1.048576e+08  1.000000e+09    400.000000
#
#         Size_in_MB
# count  9146.000000
# mean     21.514141
# std      22.588679
# min       0.008301
# 25%       4.900000
# 50%      13.000000
# 75%      30.000000
# max     100.000000

# %% [markdown]
# ## Moving further with EDA

# %%
# using f string to print min, max and average of price
print(f'Min price is {df["Price"].min()}')
print(f'Max price is {df["Price"].max()}')
print(f'Average price is {df["Price"].mean()}')
# Out:
# Min price is 0.0
# Max price is 400.0
# Average price is 1.0272733142699015

# %% [markdown]
# ## MISSING VALUES
# - Let's deal with missing values if any!

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Size_in_bytes     1695
# Size_in_MB        1695
# Rating            1474
# Current Ver          8
# Android Ver          2
# Category             1
# Genres               1
# Type                 1
# App                  0
# Reviews              0
# Installs             0
# Price                0
# Content Rating       0
# Last Updated         0
# dtype: int64

# %%
# finding missing values percentage in DataFrame
missing = round(df.isnull().sum() * 100 / len(df), 2)
missing.sort_values(ascending=False)
# Out:
# Size_in_bytes     15.64
# Size_in_MB        15.64
# Rating            13.60
# Current Ver        0.07
# Android Ver        0.02
# Category           0.01
# Genres             0.01
# Type               0.01
# App                0.00
# Reviews            0.00
# Installs           0.00
# Price              0.00
# Content Rating     0.00
# Last Updated       0.00
# dtype: float64

# %%
# find total number of missing values
df.isnull().sum().sum()
# Out:
# np.int64(4877)

# %%
# plot mising values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#  plot based on missing values percentage
# set figure size
plt.figure(figsize=(16, 6))
# plot the null values by their percentage in each column
missing_percentage= df.isnull().sum()*100/len(df)
missing_percentage.plot(kind='bar')
# set the title
plt.title('Missing Values Percentage')
# add the labels
plt.xlabel('Columns')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
# to plot those with less than 1 percent
missing_percentage[missing_percentage<1].plot(kind='bar')
# Out:
# <Axes: >
